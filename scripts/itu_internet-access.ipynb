# %% [markdown]
# # Build script for ITU Internet Access Data

# %%
import os, imp
import pandas as pd

from settings_statmart import *
import utils_statmart as us

import gen3_utils
import gen4_utils

us.verbose = True

# %% [markdown]
# Customize the below per this specfic dataset....

# %%
config = {'gen_1_dir': statmart_facts_gen1 + 'itu/',
     'gen_2_dir': statmart_facts_gen2 + 'itu/',
     'indicator': 'Percentage of population with access to the Internet',
     'indicator_category': 'ICT',
     'indicator_type': 'Internet access',
     'multiplier': .01,
     'prefix': 'internet-access',
     'suffix': 'itu'}

# %% [markdown]
# Generation 1 - The csv source file was exported from UN Data.

# %%
file_name = config["prefix"] + "_" + config["suffix"] + ".csv"
my_file = config["gen_1_dir"] + file_name
df = pd.read_csv(my_file)
df[30:50]
# Out:
#    Country or Area  Year      Value  Value Footnotes
# 30        Barbados  2008  61.400000                1
# 31        Barbados  2007  58.200000                1
# 32        Barbados  2006  55.300000                1
# 33        Barbados  2005  52.500000                1
# 34        Barbados  2004  49.800000                5
# 35        Barbados  2003  39.689627                6
# 36        Barbados  2002  27.836322                1
# 37        Barbados  2001  11.936450                1
# 38        Barbados  2000   3.973678                7
# 39         Bermuda  2012  91.299305                1
# 40         Bermuda  2011  88.336000                1
# 41         Bermuda  2010  84.210000                1
# 42         Bermuda  2009  83.250000                8
# 43         Bermuda  2008  82.300000                9
# 44         Bermuda  2007  74.350594              NaN
# 45         Bermuda  2006  69.899655              NaN
# 46         Bermuda  2005  65.447066              NaN
# 47         Bermuda  2004  60.990867              NaN
# 48         Bermuda  2003  56.522012              NaN
# 49         Bermuda  2002  52.031597              NaN
#
# [20 rows x 4 columns]

# %% [markdown]
# Generation 2 - Refines the rough csv data from Generation 1 into a standardized csv format common to all data sets. Prepares this data for importing to the database.

# %% [markdown]
# The data is separated into a sereies of lists, each containing a timeseries for one country. These lists are into a csv file called prefix\__iso3_\_suffix.csv, where prefix is the file prefix (generally related to the indicator topic), iso3 is the 3-letter country code (converted to lower case), and suffix is the suffix (usually related to the source of the data). The metadata for each series is stored in a file called prefix\__iso3_\_suffix\_meta.csv.

# %%
country_fix_map = {"Dominican Rep.":"Dominican Republic",
                   "St. Vincent and the Grenadines":"Saint Vincent and the Grenadines",
                   "Virgin Islands (U.S.)":"Virgin Islands, U.S."}
def fix_country(c):
    if c in country_fix_map:
        return country_fix_map[c]
    return c

filelist = []
us.mkdirs(config["gen_2_dir"])
for country in df["Country or Area"].unique():
    cf = df[df["Country or Area"] == country][["Year","Value"]]
    cf.columns = ["year","value"]
    cf["value"] = cf["value"].apply(lambda x: config["multiplier"] * x)
    
    #print (cf)
    cc = fix_country(country)
    iso3 = us.get_iso3_by_country(cc)
    filestem = config["prefix"] + "_" + iso3.lower() + "_" + config["suffix"]
    filename = filestem + ".csv"
    filepath = config["gen_2_dir"] + filename
    cf.to_csv(filepath, encoding="utf8", float_format='%.3f', index=False)
    meta = [("name", "%s - Percentage of population with Internet access [ITU]" % (cc)),
                ("dataset", "International Telecommunications Union database"),
                ("description", ("Pecentage of population of %s from the International Telecommunications Union") % (cc)),
                ("file", filename),
                ("filehash", us.githash(filepath)),
                ("category", config["indicator_category"]),
                ("type", config["indicator_type"]),
                ("originalsource", "International Telecommunications Union"),
                ("proximatesource", "UN Data"),
                ("columns", "year,value")]
    mf = pd.DataFrame(meta,columns = ["key","value"])
    metafile = config["gen_2_dir"] + filestem + "_meta.csv"
    mf.to_csv(metafile, encoding="utf8", index=False)
    filelist.append(filestem)
    
pd.DataFrame(filelist).to_csv(config["gen_2_dir"] + "_" + config["prefix"] + ".csv", encoding="utf8", index=False, header=False)
print("%i series saved to %s" % (len(filelist), config["gen_2_dir"]))
# Out:
# 18 series saved to C:/portal/statmart/data/facts/gen2/itu/

# %% [markdown]
# Generation 3 - Load the Generation 2 data into the database.

# %%
imp.reload(gen3_utils)
data_list = gen3_utils.get_gen2_data(config)
gen3_utils.standard_load_from_data_list(data_list)
data_list[0:3]
# Out:
# [('internet-access_atg_itu',
#   'ATG',
#   key
# name               Antigua and Barbuda - Percentage of population...
# dataset              International Telecommunications Union database
# description        Pecentage of population of Antigua and Barbuda...
# file                                     internet-access_atg_itu.csv
# filehash                    5ca916746920fe7b8745d3c2556fde929661ba28
# category                                                         ICT
# type                                                 Internet access
# originalsource                International Telecommunications Union
# proximatesource                                              UN Data
# columns                                                   year,value
# Name: value, dtype: object,
#       year  value
# 0   2012  0.590
# 1   2011  0.530
# 2   2010  0.470
# 3   2009  0.420
# 4   2008  0.380
# 5   2007  0.340
# 6   2006  0.300
# 7   2005  0.270
# 8   2004  0.243
# 9   2003  0.172
# 10  2002  0.125
# 11  2001  0.089
# 12  2000  0.065
#
# [13 rows x 2 columns]),
#  ('internet-access_bhs_itu',
#   'BHS',
#   key
# name               Bahamas - Percentage of population with Intern...
# dataset              International Telecommunications Union database
# description        Pecentage of population of Bahamas from the In...
# file                                     internet-access_bhs_itu.csv
# filehash                    7eb0b435442385ee3224fe8624fbadbe6c20132d
# category                                                         ICT
# type                                                 Internet access
# originalsource                International Telecommunications Union
# proximatesource                                              UN Data
# columns                                                   year,value
# Name: value, dtype: object,
#       year  value
# 0   2012  0.717
# 1   2011  0.650
# 2   2010  0.430
# 3   2009  0.339
# 4   2008  0.315
# 5   2007  0.270
# 6   2006  0.260
# 7   2005  0.250
# 8   2004  0.220
# 9   2003  0.200
# 10  2002  0.180
# 11  2001  0.118
# 12  2000  0.080
#
# [13 rows x 2 columns]),
#  ('internet-access_brb_itu',
#   'BRB',
#   key
# name               Barbados - Percentage of population with Inter...
# dataset              International Telecommunications Union database
# description        Pecentage of population of Barbados from the I...
# file                                     internet-access_brb_itu.csv
# filehash                    8872d7d587cda23add390fb405b029b4af15f393
# category                                                         ICT
# type                                                 Internet access
# originalsource                International Telecommunications Union
# proximatesource                                              UN Data
# columns                                                   year,value
# Name: value, dtype: object,
#       year  value
# 0   2012  0.733
# 1   2011  0.718
# 2   2010  0.681
# 3   2009  0.647
# 4   2008  0.614
# 5   2007  0.582
# 6   2006  0.553
# 7   2005  0.525
# 8   2004  0.498
# 9   2003  0.397
# 10  2002  0.278
# 11  2001  0.119
# 12  2000  0.040
#
# [13 rows x 2 columns])]

# %% [markdown]
# Generation 4 - Build a php file that uses javascript to generate SVGs using the data in the database

# %%
import imp
imp.reload(gen4_utils)
config = gen4_utils.build_gen4_config(config)
page = gen4_utils.build_d3_line_graph(config)

# %%
filelist
# Out:
# ['internet-access_atg_itu',
#  'internet-access_bhs_itu',
#  'internet-access_brb_itu',
#  'internet-access_bmu_itu',
#  'internet-access_cub_itu',
#  'internet-access_dma_itu',
#  'internet-access_dom_itu',
#  'internet-access_grd_itu',
#  'internet-access_guy_itu',
#  'internet-access_hti_itu',
#  'internet-access_jam_itu',
#  'internet-access_pri_itu',
#  'internet-access_kna_itu',
#  'internet-access_lca_itu',
#  'internet-access_vct_itu',
#  'internet-access_sur_itu',
#  'internet-access_tto_itu',
#  'internet-access_vir_itu']

# %%
str = "timeseries.php?s="
str = str + ",".join(filelist)
str
# Out:
# 'timeseries.php?s=internet-access_atg_itu,internet-access_bhs_itu,internet-access_brb_itu,internet-access_bmu_itu,internet-access_cub_itu,internet-access_dma_itu,internet-access_dom_itu,internet-access_grd_itu,internet-access_guy_itu,internet-access_hti_itu,internet-access_jam_itu,internet-access_pri_itu,internet-access_kna_itu,internet-access_lca_itu,internet-access_vct_itu,internet-access_sur_itu,internet-access_tto_itu,internet-access_vir_itu'
