# %% [markdown]
# This script imports DESA population data into the database. The data can be found in the /facts/gen2/desa directory. The two data files per country are pop\__iso3_\_desa.csv, containing the time series, and pop\__iso3_\_desa_meta.csv, containing meta data.
#
# This script will import data from all files listed in \_pop.csv.

# %%
import os.path
import pandas as pd
from hashlib import sha1
import pymysql
import pandas.io.sql as psql

import statmart_util as smu

from statmart_config import *

gen2Dir = statmart_facts_gen2 + "desa/"

prefix = "pop"
suffix = "desa"

# %% [markdown]
# Bring in all the data and metadata using the statmart_util.get_gen2_data function. The data is returned as an array of tupples. Each tupple contains the ISO3 value, the meta DataFrame, and the dataset DataFrame.

# %%
data_list = smu.get_gen2_data(gen2Dir, prefix)
data_list[0:5] # have a look at a sample our data
# Out:
# [('pop_atg_desa',
#   'ATG',
#   key
# name           Antigua and Barbuda - Population estimates (19...
# dataset                       UN DESA world population estimates
# description    Population estimates for Antigua and Barbuda f...
# file                                            pop_atg_desa.csv
# filehash                6d9539eb4cc41d651edee34bbd6bf1141fcd3c58
# category                                            Demographics
# type                                                  Population
# columns                                               year,value
# Name: value, dtype: object,
#   year
# 1950    46301
# 1951    48306
# 1952    49887
# 1953    51092
# 1954    51979
# 1955    52611
# 1956    53062
# 1957    53411
# 1958    53744
# 1959    54143
# 1960    54681
# 1961    55403
# 1962    56311
# 1963    57368
# 1964    58500
# ...
# 1996    70245
# 1997    72232
# 1998    74206
# 1999    76041
# 2000    77648
# 2001    78972
# 2002    80030
# 2003    80904
# 2004    81718
# 2005    82565
# 2006    83467
# 2007    84397
# 2008    85349
# 2009    86300
# 2010    87233
# Name: value, Length: 61, dtype: int64),
#  ('pop_abw_desa',
#   'ABW',
#   key
# name           Aruba - Population estimates (1950-2010) [UN D...
# dataset                       UN DESA world population estimates
# description    Population estimates for Aruba from the 2012 R...
# file                                            pop_abw_desa.csv
# filehash                2e41cea564df87670b6b0e5ee2b4a7466f31e2df
# category                                            Demographics
# type                                                  Population
# columns                                               year,value
# Name: value, dtype: object,
#   year
# 1950    38066
# 1951    38263
# 1952    38965
# 1953    40149
# 1954    41763
# 1955    43727
# 1956    45933
# 1957    48242
# 1958    50499
# 1959    52535
# 1960    54208
# 1961    55435
# 1962    56226
# 1963    56697
# 1964    57029
# ...
# 1996     83195
# 1997     85447
# 1998     87276
# 1999     89004
# 2000     90858
# 2001     92894
# 2002     94995
# 2003     97015
# 2004     98742
# 2005    100031
# 2006    100830
# 2007    101219
# 2008    101344
# 2009    101418
# 2010    101597
# Name: value, Length: 61, dtype: int64),
#  ('pop_bhs_desa',
#   'BHS',
#   key
# name           Bahamas - Population estimates (1950-2010) [UN...
# dataset                       UN DESA world population estimates
# description    Population estimates for Bahamas from the 2012...
# file                                            pop_bhs_desa.csv
# filehash                de86e0af5a95a2507342b32db2ffbe0fe9ccce7c
# category                                            Demographics
# type                                                  Population
# columns                                               year,value
# Name: value, dtype: object,
#   year
# 1950     79088
# 1951     79984
# 1952     81428
# 1953     83371
# 1954     85776
# 1955     88619
# 1956     91893
# 1957     95604
# 1958     99767
# 1959    104406
# 1960    109526
# 1961    115108
# 1962    121083
# 1963    127331
# 1964    133697
# ...
# 1996    283678
# 1997    286845
# 1998    289926
# 1999    293442
# 2000    297759
# 2001    303005
# 2002    309039
# 2003    315624
# 2004    322400
# 2005    329088
# 2006    335622
# 2007    342049
# 2008    348340
# 2009    354492
# 2010    360498
# Name: value, Length: 61, dtype: int64),
#  ('pop_brb_desa',
#   'BRB',
#   key
# name           Barbados - Population estimates (1950-2010) [U...
# dataset                       UN DESA world population estimates
# description    Population estimates for Barbados from the 201...
# file                                            pop_brb_desa.csv
# filehash                6bea78fc63483ddc4f63bbc8bc8ca2f2f774a107
# category                                            Demographics
# type                                                  Population
# columns                                               year,value
# Name: value, dtype: object,
#   year
# 1950    210995
# 1951    215685
# 1952    219607
# 1953    222772
# 1954    225223
# 1955    227030
# 1956    228297
# 1957    229153
# 1958    229758
# 1959    230276
# 1960    230858
# 1961    231599
# 1962    232514
# 1963    233520
# 1964    234478
# ...
# 1996    263884
# 1997    264606
# 1998    265370
# 1999    266220
# 2000    267190
# 2001    268296
# 2002    269524
# 2003    270844
# 2004    272205
# 2005    273568
# 2006    274923
# 2007    276277
# 2008    277634
# 2009    279006
# 2010    280396
# Name: value, Length: 61, dtype: int64),
#  ('pop_blz_desa',
#   'BLZ',
#   key
# name           Belize - Population estimates (1950-2010) [UN ...
# dataset                       UN DESA world population estimates
# description    Population estimates for Belize from the 2012 ...
# file                                            pop_blz_desa.csv
# filehash                4c77de186b2c959b5dac356e7d60be4bad054526
# category                                            Demographics
# type                                                  Population
# columns                                               year,value
# Name: value, dtype: object,
#   year
# 1950     68918
# 1951     71243
# 1952     73428
# 1953     75554
# 1954     77686
# 1955     79872
# 1956     82140
# 1957     84503
# 1958     86956
# 1959     89483
# 1960     92068
# 1961     94701
# 1962     97389
# 1963    100166
# 1964    103070
# ...
# 1996    212375
# 1997    218484
# 1998    225083
# 1999    231860
# 2000    238586
# 2001    245198
# 2002    251766
# 2003    258346
# 2004    265040
# 2005    271920
# 2006    278985
# 2007    286196
# 2008    293544
# 2009    301016
# 2010    308595
# Name: value, Length: 61, dtype: int64)]

# %% [markdown]
# Insert the data from data_list into the MySQL database

# %%
with smu.get_db_connection() as cursor:
    for (series_key, iso3, meta, data) in data_list:
        cursor.execute("SELECT ID FROM location WHERE iso3 = %s AND divisionname IS NULL AND city IS NULL", [iso3])
        locationid = list(cursor)[0][0]
        
        series_fields = "identifier, dataset, file, filehash, category, type, name, description"
        insert_series = "INSERT INTO SERIES (" + series_fields +") VALUES (%s, %s, %s, %s, %s, %s, %s, %s)" 
        values = [series_key]
        for field in series_fields.split(",")[1:]:
            values.append(meta[field.strip()])
        cursor.execute(insert_series, values)
        
        for date in data.index:
            cursor.execute("SELECT ID FROM date WHERE year = %s AND month IS NULL AND day IS NULL", [str(date)])
            dateid = list(cursor)[0][0]
            observation_fields = "series, locationid, dateid, value" 
            #full list of fields: `OBSERVATIONID`, `SERIESID`, `LOCATIONID`, `DATEID`, `NOTEID`, `DESCRIPTIONID`, `VALUE`, `UNITID`, `STATUSID`
            insert_observation = "INSERT INTO observation(" + observation_fields + ") VALUES (%s, %s, %s, %s)"
            values  = [series_key, locationid, dateid, str(data.ix[date])]
            cursor.execute(insert_observation, values)
        cursor.execute("COMMIT")

# %% [markdown]
# Here is an example of how to make an SQL query to retrieve data in the series:

# %%
df = ""
with smu.get_db_connection() as cursor:
    query = """
            SELECT D.year, L.iso3, O.value 
            FROM observation as O 
            INNER JOIN date as D    ON O.dateid = D.id
            INNER JOIN location as L   ON O.locationid = L.id
            INNER JOIN series as S 	ON O.series = S.identifier
            WHERE
                (L.iso3 = "TTO" OR
                L.iso3 = "BRB")
            AND S.dataset = 'UN DESA world population estimates'
            ORDER BY D.year, L.iso3
            """
    df = psql.frame_query(query, con=cursor.connection)

df
# Out:
#     year iso3    value
# 0   1950  BRB   210995
# 1   1950  TTO   645628
# 2   1951  BRB   215685
# 3   1951  TTO   658830
# 4   1952  BRB   219607
# 5   1952  TTO   675742
# 6   1953  BRB   222772
# 7   1953  TTO   695467
# 8   1954  BRB   225223
# 9   1954  TTO   717161
# 10  1955  BRB   227030
# 11  1955  TTO   740036
# 12  1956  BRB   228297
# 13  1956  TTO   763355
# 14  1957  BRB   229153
# 15  1957  TTO   786438
# 16  1958  BRB   229758
# 17  1958  TTO   808663
# 18  1959  BRB   230276
# 19  1959  TTO   829489
# 20  1960  BRB   230858
# 21  1960  TTO   848481
# 22  1961  BRB   231599
# 23  1961  TTO   865356
# 24  1962  BRB   232514
# 25  1962  TTO   880019
# 26  1963  BRB   233520
# 27  1963  TTO   892571
# 28  1964  BRB   234478
# 29  1964  TTO   903272
# 30  1965  BRB   235294
# 31  1965  TTO   912419
# 32  1966  BRB   235936
# 33  1966  TTO   919902
# 34  1967  BRB   236466
# 35  1967  TTO   925918
# 36  1968  BRB   236997
# 37  1968  TTO   931466
# 38  1969  BRB   237680
# 39  1969  TTO   937846
# 40  1970  BRB   238616
# 41  1970  TTO   945996
# 42  1971  BRB   239864
# 43  1971  TTO   956364
# 44  1972  BRB   241367
# 45  1972  TTO   968742
# 46  1973  BRB   242971
# 47  1973  TTO   982594
# 48  1974  BRB   244453
# 49  1974  TTO   997052
# 50  1975  BRB   245663
# 51  1975  TTO  1011487
# 52  1976  BRB   246536
# 53  1976  TTO  1025655
# 54  1977  BRB   247136
# 55  1977  TTO  1039757
# 56  1978  BRB   247592
# 57  1978  TTO  1054109
# 58  1979  BRB   248095
# 59  1979  TTO  1069199
#      ...  ...      ...
#
# [122 rows x 3 columns]
