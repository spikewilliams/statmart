# %% [markdown]
# # Facebook usage by gender

# %%
import os, imp
import pandas as pd

from settings_statmart import *
import utils_statmart as us

import gen3_utils
import gen4_utils

us.verbose = True

# %% [markdown]
# Customize the below per this specfic dataset....

# %%
config = {'gen_1_dir': statmart_facts_gen1 + 'eclac/',
     'gen_2_dir': statmart_facts_gen2 + 'eclac/fb/',
     'gen_4_dir': statmart_view_gen4 + 'eclac/fb/',
     'indicator': 'Facebook audience size',
     'indicator_category': 'Social',
     'indicator_type': 'ICT',
     'multiplier': 1000,
     'prefix': 'eclac',
     'suffix': 'fb'}

# %% [markdown]
# Generation 1 - This data was collected via the Facebook Advertising interface - https://www.facebook.com/ads/create

# %%
file_name = "FacebookData.xlsx"
popfile = config["gen_1_dir"] + file_name
xlfile = pd.ExcelFile(popfile)
xlfile.sheet_names # The source file has several different estimates available. We are just using the base scenario ('ESTIMATES'), plus the 'NOTES' sheet.
# Out:
# ['meta', 'data', 'Sheet3']

# %% [markdown]
# Generation 2 - Refines the rough csv data from Generation 1 into a standardized csv format common to all data sets. Prepares this data for importing to the database.

# %% [markdown]
# First, create the DataFrame with all population information. The "Country code" column contains the ISO 3166 numeric value, but as an integer, rather than as 3-numeral string padded by zeros. So we fix this to be in line with the ISO spec, and, hence, with our data. We also rename the Country code field to match the name in our schema.

# %%
df = xlfile.parse("data", header=0)
df = df.rename(columns={"Country":"name", "Men":"male", "Women":"female", "Total":"total"})
df[0:4] # sample our data
# Out:
#                   name   male  female   total     % Men   % Women
# 0             Anguilla   3000    3600    6600  0.454545  0.545455
# 1  Antigua and Barbuda  15000   19200   34200  0.438596  0.561404
# 2                Aruba  28000   34000   62000  0.451613  0.548387
# 3              Bahamas  80000   98000  178000  0.449438  0.550562
#
# [4 rows x 6 columns]

# %%
country_dict = us.load_carib_country_dict(key_column="name") # Here we filter in only Caribbean countries
carib = pd.DataFrame(country_dict).T
cf = pd.merge(carib,df, on="name")
cf = cf.set_index("iso3")
cf[["male","female","total"]]
#cf[0:5] # look at a sample
# Out:
#         male   female    total
# iso3
# AIA     3000     3600     6600
# ATG    15000    19200    34200
# ABW    28000    34000    62000
# BHS    80000    98000   178000
# BRB    58000    70000   128000
# BLZ    48000    50000    98000
# BMU    14000    17600    31600
# VGB     5200     5800    11000
# CYM    14600    16000    30600
# DMA    13000    15000    28000
# GRD    18600    19800    38400
# GLP    86000    96000   182000
# GUY    76000    94000   170000
# HTI   460000   260000   720000
# JAM   360000   420000   780000
# MSR     1120     1040     2160
# PRI   840000  1020000  1860000
# KNA    10800    12400    23200
# LCA    30000    34000    64000
# TTO   240000   280000   520000
# TCA     8000     7600    15600
#
# [21 rows x 3 columns]

# %% [markdown]
# Next, parse out the notes from the notes sheet. These are a bunch of values in rows, looking like "(22) Refers to Bonaire, Saba and Sint Eustatius."  We need to map the value in parens to something that can be related to the "Notes" field of the main dataframe. This uses a flag to ensure that notes are run twice against the same DataFrame.

# %%
if not hasattr(cf,"notesFlag"):
    noteMap = {}
    notes = xlfile.parse("NOTES").transpose()
    for col in notes.columns:
        (noteid, note) = notes[col][0].split(") ",1)
        noteid = noteid[1:]
        noteMap[noteid] = note
    cf["Notes"] = cf["Notes"].dropna().apply(lambda x: noteMap[str(x)])
else:
    print("WARNING: you must reinitialize the DataFrame before running this code a second time.")        
cf.notesFlag = True
cf[10:14]
# Out:
#      cepalid iso2 isonum        name  Index    Variant  \
# iso3
# GRD      234   GD    308     Grenada    197  Estimates
# GLP    31800   GP    312  Guadeloupe    198  Estimates
# GUY      237   GY    328      Guyana    229  Estimates
# HTI      238   HT    332       Haiti    199  Estimates
#
#      Major area, region, country or area  \
# iso3
# GRD                              Grenada
# GLP                           Guadeloupe
# GUY                               Guyana
# HTI                                Haiti
#
#                                                   Notes     1950     1951  \
# iso3
# GRD                                                 NaN    76676    76626
# GLP   Including Saint-Barthélemy and Saint-Martin (F...   209999   213055
# GUY                                                 NaN   406562   423490
# HTI                                                 NaN  3221277  3275970
#
#          1952     1953     1954     1955     1956     1957     1958     1959  \
# iso3
# GRD     77135    78103    79432    81028    82797    84647    86495    88256
# GLP    217248   222551   228874   236061   243886   252057   260232   268044
# GUY    439143   454072   468711   483376   498266   513462   528938   544592
# HTI   3332684  3391562  3452713  3516213  3582104  3650396  3721064  3794054
#
#          1960     1961
# iso3
# GRD     89861    91260 ...
# GLP    275169   281412 ...
# GUY    560296   575976 ...
# HTI   3869288  3946666 ...
#
# [4 rows x 69 columns]

# %% [markdown]
# Save each list of population estimates into a csv file called pop\__iso3_\_desa.csv, where iso3 is the 3-letter country code, converted to lower case. Save the metadata in a file called pop\__iso3_\_desa\_meta.csv.

# %%
filelist = []
tf = cf.T
mf = ""
for col in tf.columns:
    line = tf[col]
    filestem = config["prefix"] + "_" + col.lower() + "_" + config["suffix"]
    filename = filestem + ".csv"
    filepath = config["gen_2_dir"] + filename
    line[8:].to_csv(filepath, encoding="utf8", index=True, header=["value"], index_label="year")
    
    meta = [("name", "%s - Population estimates (1950-2010) [UN DESA]" % (line.ix["name"])),
                ("dataset", "UN DESA world population estimates"),
                ("description", ("Population estimates for %s from the 2012 Revision of the World Population Prospects, produced by the " + \
                    "Population Division of the United Nations Department of Economic and Social Affairs") % (line.ix["name"])),
                ("file", filename),
                ("filehash", us.githash(filepath)),
                ("category", config["indicator_category"]),
                ("type", config["indicator_type"]),
                ("originalsource", "UN Department of Economic and Social Affairs: Population Divison"),
                ("columns", "year,value")]
    mf = pd.DataFrame(meta,columns = ["key","value"])
    metafile = config["gen_2_dir"] + filestem + "_meta.csv"
    mf.to_csv(metafile, encoding="utf8", index=False)
    filelist.append(filestem)
    
pd.DataFrame(filelist).to_csv(config["gen_2_dir"] + "_" + config["prefix"] + ".csv", encoding="utf8", index=False, header=False)
print("%i series saved to %s" % (len(filelist), config["gen_2_dir"]))
# Out:
# 26 series saved to C:/portal/statmart/data/facts/gen2/desa/pop/

# %% [markdown]
# Generation 3 - Load the Generation 2 data into the database.

# %%
imp.reload(gen3_utils)
data_list = gen3_utils.get_gen2_data(config)
gen3_utils.standard_load_from_data_list(data_list)
data_list[0:3]
# Out:
# [('pop_atg_desa',
#   'ATG',
#   key
# name              Antigua and Barbuda - Population estimates (19...
# dataset                          UN DESA world population estimates
# description       Population estimates for Antigua and Barbuda f...
# file                                               pop_atg_desa.csv
# filehash                   6d9539eb4cc41d651edee34bbd6bf1141fcd3c58
# category                                                Demographic
# type                                                     Population
# originalsource    UN Department of Economic and Social Affairs: ...
# columns                                                  year,value
# Name: value, dtype: object,
#       year  value
# 0   1950  46301
# 1   1951  48306
# 2   1952  49887
# 3   1953  51092
# 4   1954  51979
# 5   1955  52611
# 6   1956  53062
# 7   1957  53411
# 8   1958  53744
# 9   1959  54143
# 10  1960  54681
# 11  1961  55403
# 12  1962  56311
# 13  1963  57368
# 14  1964  58500
# 15  1965  59653
# 16  1966  60818
# 17  1967  62002
# 18  1968  63176
# 19  1969  64307
# 20  1970  65369
# 21  1971  66338
# 22  1972  67205
# 23  1973  67972
# 24  1974  68655
# 25  1975  69253
# 26  1976  69782
# 27  1977  70223
# 28  1978  70508
# 29  1979  70553
# 30  1980  70301
# 31  1981  69750
# 32  1982  68950
# 33  1983  67958
# 34  1984  66863
# 35  1985  65744
# 36  1986  64605
# 37  1987  63484
# 38  1988  62538
# 39  1989  61967
# 40  1990  61906
# 41  1991  62412
# 42  1992  63434
# 43  1993  64867
# 44  1994  66550
# 45  1995  68349
# 46  1996  70245
# 47  1997  72232
# 48  1998  74206
# 49  1999  76041
# 50  2000  77648
# 51  2001  78972
# 52  2002  80030
# 53  2003  80904
# 54  2004  81718
# 55  2005  82565
# 56  2006  83467
# 57  2007  84397
# 58  2008  85349
# 59  2009  86300
#      ...    ...
#
# [61 rows x 2 columns]),
#  ('pop_bhs_desa',
#   'BHS',
#   key
# name              Bahamas - Population estimates (1950-2010) [UN...
# dataset                          UN DESA world population estimates
# description       Population estimates for Bahamas from the 2012...
# file                                               pop_bhs_desa.csv
# filehash                   de86e0af5a95a2507342b32db2ffbe0fe9ccce7c
# category                                                Demographic
# type                                                     Population
# originalsource    UN Department of Economic and Social Affairs: ...
# columns                                                  year,value
# Name: value, dtype: object,
#       year   value
# 0   1950   79088
# 1   1951   79984
# 2   1952   81428
# 3   1953   83371
# 4   1954   85776
# 5   1955   88619
# 6   1956   91893
# 7   1957   95604
# 8   1958   99767
# 9   1959  104406
# 10  1960  109526
# 11  1961  115108
# 12  1962  121083
# 13  1963  127331
# 14  1964  133697
# 15  1965  140049
# 16  1966  146364
# 17  1967  152607
# 18  1968  158629
# 19  1969  164250
# 20  1970  169356
# 21  1971  173867
# 22  1972  177844
# 23  1973  181489
# 24  1974  185097
# 25  1975  188882
# 26  1976  192905
# 27  1977  197118
# 28  1978  201511
# 29  1979  206038
# 30  1980  210660
# 31  1981  215404
# 32  1982  220274
# 33  1983  225184
# 34  1984  230014
# 35  1985  234684
# 36  1986  239135
# 37  1987  243397
# 38  1988  247585
# 39  1989  251863
# 40  1990  256338
# 41  1991  261101
# 42  1992  266097
# 43  1993  271105
# 44  1994  275820
# 45  1995  280050
# 46  1996  283678
# 47  1997  286845
# 48  1998  289926
# 49  1999  293442
# 50  2000  297759
# 51  2001  303005
# 52  2002  309039
# 53  2003  315624
# 54  2004  322400
# 55  2005  329088
# 56  2006  335622
# 57  2007  342049
# 58  2008  348340
# 59  2009  354492
#      ...     ...
#
# [61 rows x 2 columns]),
#  ('pop_brb_desa',
#   'BRB',
#   key
# name              Barbados - Population estimates (1950-2010) [U...
# dataset                          UN DESA world population estimates
# description       Population estimates for Barbados from the 201...
# file                                               pop_brb_desa.csv
# filehash                   6bea78fc63483ddc4f63bbc8bc8ca2f2f774a107
# category                                                Demographic
# type                                                     Population
# originalsource    UN Department of Economic and Social Affairs: ...
# columns                                                  year,value
# Name: value, dtype: object,
#       year   value
# 0   1950  210995
# 1   1951  215685
# 2   1952  219607
# 3   1953  222772
# 4   1954  225223
# 5   1955  227030
# 6   1956  228297
# 7   1957  229153
# 8   1958  229758
# 9   1959  230276
# 10  1960  230858
# 11  1961  231599
# 12  1962  232514
# 13  1963  233520
# 14  1964  234478
# 15  1965  235294
# 16  1966  235936
# 17  1967  236466
# 18  1968  236997
# 19  1969  237680
# 20  1970  238616
# 21  1971  239864
# 22  1972  241367
# 23  1973  242971
# 24  1974  244453
# 25  1975  245663
# 26  1976  246536
# 27  1977  247136
# 28  1978  247592
# 29  1979  248095
# 30  1980  248784
# 31  1981  249696
# 32  1982  250780
# 33  1983  251979
# 34  1984  253193
# 35  1985  254354
# 36  1986  255450
# 37  1987  256500
# 38  1988  257497
# 39  1989  258442
# 40  1990  259336
# 41  1991  260175
# 42  1992  260963
# 43  1993  261714
# 44  1994  262441
# 45  1995  263165
# 46  1996  263884
# 47  1997  264606
# 48  1998  265370
# 49  1999  266220
# 50  2000  267190
# 51  2001  268296
# 52  2002  269524
# 53  2003  270844
# 54  2004  272205
# 55  2005  273568
# 56  2006  274923
# 57  2007  276277
# 58  2008  277634
# 59  2009  279006
#      ...     ...
#
# [61 rows x 2 columns])]

# %% [markdown]
# Generation 4 - Build a php file that uses javascript to generate SVGs using the data in the database

# %%
import imp
imp.reload(gen4_utils)
config = gen4_utils.build_gen4_config(config)
page = gen4_utils.build_d3_line_graph(config)

# %%
filelist
# Out:
# ['pop_atg_desa',
#  'pop_bhs_desa',
#  'pop_brb_desa',
#  'pop_bmu_desa',
#  'pop_blz_desa',
#  'pop_vgb_desa',
#  'pop_cym_desa',
#  'pop_cub_desa',
#  'pop_dma_desa',
#  'pop_dom_desa',
#  'pop_grd_desa',
#  'pop_glp_desa',
#  'pop_guy_desa',
#  'pop_hti_desa',
#  'pop_jam_desa',
#  'pop_msr_desa',
#  'pop_abw_desa',
#  'pop_pri_desa',
#  'pop_kna_desa',
#  'pop_aia_desa',
#  'pop_lca_desa',
#  'pop_vct_desa',
#  'pop_sur_desa',
#  'pop_tto_desa',
#  'pop_tca_desa',
#  'pop_vir_desa']

# %%
country_dict
# Out:
# {'Anguilla': {'cepalid': '213',
#   'iso2': 'AI',
#   'iso3': 'AIA',
#   'isonum': '660',
#   'name': 'Anguilla'},
#  'Antigua and Barbuda': {'cepalid': '214',
#   'iso2': 'AG',
#   'iso3': 'ATG',
#   'isonum': '028',
#   'name': 'Antigua and Barbuda'},
#  'Aruba': {'cepalid': '217',
#   'iso2': 'AW',
#   'iso3': 'ABW',
#   'isonum': '533',
#   'name': 'Aruba'},
#  'Bahamas': {'cepalid': '218',
#   'iso2': 'BS',
#   'iso3': 'BHS',
#   'isonum': '044',
#   'name': 'Bahamas'},
#  'Barbados': {'cepalid': '219',
#   'iso2': 'BB',
#   'iso3': 'BRB',
#   'isonum': '052',
#   'name': 'Barbados'},
#  'Belize': {'cepalid': '220',
#   'iso2': 'BZ',
#   'iso3': 'BLZ',
#   'isonum': '084',
#   'name': 'Belize'},
#  'Bermuda': {'cepalid': '31799',
#   'iso2': 'BM',
#   'iso3': 'BMU',
#   'isonum': '060',
#   'name': 'Bermuda'},
#  'British Virgin Islands': {'cepalid': '243',
#   'iso2': 'VG',
#   'iso3': 'VGB',
#   'isonum': '092',
#   'name': 'British Virgin Islands'},
#  'Cayman Islands': {'cepalid': '20442',
#   'iso2': 'KY',
#   'iso3': 'CYM',
#   'isonum': '136',
#   'name': 'Cayman Islands'},
#  'Cuba': {'cepalid': '249',
#   'iso2': 'CU',
#   'iso3': 'CUB',
#   'isonum': '192',
#   'name': 'Cuba'},
#  'Dominica': {'cepalid': '228',
#   'iso2': 'DM',
#   'iso3': 'DMA',
#   'isonum': '212',
#   'name': 'Dominica'},
#  'Dominican Republic': {'cepalid': '264',
#   'iso2': 'DO',
#   'iso3': 'DOM',
#   'isonum': '214',
#   'name': 'Dominican Republic'},
#  'Grenada': {'cepalid': '234',
#   'iso2': 'GD',
#   'iso3': 'GRD',
#   'isonum': '308',
#   'name': 'Grenada'},
#  'Guadeloupe': {'cepalid': '31800',
#   'iso2': 'GP',
#   'iso3': 'GLP',
#   'isonum': '312',
#   'name': 'Guadeloupe'},
#  'Guyana': {'cepalid': '237',
#   'iso2': 'GY',
#   'iso3': 'GUY',
#   'isonum': '328',
#   'name': 'Guyana'},
#  'Haiti': {'cepalid': '238',
#   'iso2': 'HT',
#   'iso3': 'HTI',
#   'isonum': '332',
#   'name': 'Haiti'},
#  'Jamaica': {'cepalid': '246',
#   'iso2': 'JM',
#   'iso3': 'JAM',
#   'isonum': '388',
#   'name': 'Jamaica'},
#  'Montserrat': {'cepalid': '236',
#   'iso2': 'MS',
#   'iso3': 'MSR',
#   'isonum': '500',
#   'name': 'Montserrat'},
#  'Puerto Rico': {'cepalid': '261',
#   'iso2': 'PR',
#   'iso3': 'PRI',
#   'isonum': '630',
#   'name': 'Puerto Rico'},
#  'Saint Kitts and Nevis': {'cepalid': '257',
#   'iso2': 'KN',
#   'iso3': 'KNA',
#   'isonum': '659',
#   'name': 'Saint Kitts and Nevis'},
#  'Saint Lucia': {'cepalid': '262',
#   'iso2': 'LC',
#   'iso3': 'LCA',
#   'isonum': '662',
#   'name': 'Saint Lucia'},
#  'Saint Vincent and The Grenadines': {'cepalid': '260',
#   'iso2': 'VC',
#   'iso3': 'VCT',
#   'isonum': '670',
#   'name': 'Saint Vincent and The Grenadines'},
#  'Suriname': {'cepalid': '263',
#   'iso2': 'SR',
#   'iso3': 'SUR',
#   'isonum': '740',
#   'name': 'Suriname'},
#  'Trinidad and Tobago': {'cepalid': '256',
#   'iso2': 'TT',
#   'iso3': 'TTO',
#   'isonum': '780',
#   'name': 'Trinidad and Tobago'},
#  'Turks and Caicos Islands': {'cepalid': '3272',
#   'iso2': 'TC',
#   'iso3': 'TCA',
#   'isonum': '796',
#   'name': 'Turks and Caicos Islands'},
#  'U.S. Virgin Islands': {'cepalid': '245',
#   'iso2': 'VI',
#   'iso3': 'VIR',
#   'isonum': '850',
#   'name': 'U.S. Virgin Islands'}}
