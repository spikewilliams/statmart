# %% [markdown]
# # Load script for CEPALStat indicator \#307: contraception usage.

# %% [markdown]
# This script imports csv formatted data (generation 2) into the database (generation 3.)
#
# This script will import data from all files listed in "data/facts/gen2/cepalstat/contraception/_contraception.csv".

# %%
import os.path
import pandas as pd
import pymysql
import pandas.io.sql as psql

from s0000_statmart_settings import *
import s0001_statmart_utils as statmart_utils
import s3001_load_utils as load_utils

# %% [markdown]
# Settings:

# %%
gen_2_dir = statmart_facts_gen2 + "cepalstat/contraception/"

prefix = "contraception"
suffix = "cepalstat"
indicator_id = "307"

# %% [markdown]
# Bring in all the data and metadata using the load\_utils.get\_gen2\_data function. The data is returned as an array of tupples. Each tupple contains the "series key", the ISO3 value of the country, the meta DataFrame, and the dataset DataFrame.

# %%
data_list = load_utils.get_gen2_data(gen_2_dir, prefix)
data_list[0:3] # have a look at a sample of the data
# Out:
# [('contraception_blz_cepalstat',
#   'BLZ',
#   key
# name                          Belize - Contraceptive use [CEPALStat]
# originalsource     United Nations Statistics Division: Millennium...
# proximatesource                                            CEPALStat
# dataset            Contraceptive prevalence rate among married wo...
# description        Corresponds to the percentage of women who are...
# category                                                      Social
# type                                                          Health
# file                                 contraception_blz_cepalstat.csv
# filehash                    ece62554eaceb1f90c2b34ee20a57a6066862242
# columns                                      year,value,source,notes
# Name: value, dtype: object,
#         value                                             source  \
# year
# 1991   46.7  United Nations Statistics Division: Millennium...
# 1999   56.1  United Nations Statistics Division: Millennium...
# 2006   34.3  United Nations Statistics Division: Millennium...
# 2011   55.2  United Nations Statistics Division: Millennium...
#
#                                                   notes
# year
# 1991  Ages 15-44|The figure is the one produced and ...
# 1999  Years of survey: 1995-1996|The figure is the o...
# 2006  Data pertain to all women of reproductive age,...
# 2011  The figure is the one produced and disseminate...
#
# [4 rows x 3 columns]),
#  ('contraception_cub_cepalstat',
#   'CUB',
#   key
# name                            Cuba - Contraceptive use [CEPALStat]
# originalsource     United Nations Statistics Division: Millennium...
# proximatesource                                            CEPALStat
# dataset            Contraceptive prevalence rate among married wo...
# description        Corresponds to the percentage of women who are...
# category                                                      Social
# type                                                          Health
# file                                 contraception_cub_cepalstat.csv
# filehash                    0572632cbe0f111e31528229fc2991a6fdb36da0
# columns                                      year,value,source,notes
# Name: value, dtype: object,
#         value                                             source  \
# year
# 2000   73.3  United Nations Statistics Division: Millennium...
# 2006   72.6  United Nations Statistics Division: Millennium...
# 2011   74.3  United Nations Statistics Division: Millennium...
#
#                                                   notes
# year
# 2000  Data pertain to sexually active women of repro...
# 2006  Data pertain to all women of reproductive age,...
# 2011  Years of the survey 2010-2011|The figure is th...
#
# [3 rows x 3 columns]),
#  ('contraception_dom_cepalstat',
#   'DOM',
#   key
# name               Dominican Republic - Contraceptive use [CEPALS...
# originalsource     United Nations Statistics Division: Millennium...
# proximatesource                                            CEPALStat
# dataset            Contraceptive prevalence rate among married wo...
# description        Corresponds to the percentage of women who are...
# category                                                      Social
# type                                                          Health
# file                                 contraception_dom_cepalstat.csv
# filehash                    b68b79cf016ed526cfc8ca932e96d30be0a6e774
# columns                                      year,value,source,notes
# Name: value, dtype: object,
#         value                                             source  \
# year
# 1991   56.4  United Nations Statistics Division: Millennium...
# 1996   63.7  United Nations Statistics Division: Millennium...
# 1999   69.2  United Nations Statistics Division: Millennium...
# 2000   64.7  United Nations Statistics Division: Millennium...
# 2002   69.8  United Nations Statistics Division: Millennium...
# 2006   61.3  United Nations Statistics Division: Millennium...
# 2007   72.9  United Nations Statistics Division: Millennium...
#
#                                                   notes
# year
# 1991  The figure is the one produced and disseminate...
# 1996  The figure is the one produced and disseminate...
# 1999  Adjusted|The figure is the one produced and di...
# 2000  The figure is the one produced and disseminate...
# 2002  The figure is the one produced and disseminate...
# 2006  The figure is the one produced and disseminate...
# 2007  The figure is the one produced and disseminate...
#
# [7 rows x 3 columns])]

# %% [markdown]
# Insert the data from data_list into the MySQL database

# %%
load_utils.standard_load_from_data_list(data_list)

# %% [markdown]
# Here is an example of how to make an SQL query to retrieve data in the series:

# %%
df = ""
with smu.get_db_connection() as cursor:
    query = """
            SELECT L.iso3, L.countryname, D.year, O.value 
            FROM observation as O 
            INNER JOIN date as D    ON O.dateid = D.id
            INNER JOIN location as L    ON O.locationid = L.id
            WHERE O.series like 'contraception\_%\_cepalstat'
            ORDER BY D.year
            """
    df = psql.frame_query(query, con=cursor.connection)
    
df
# Out:
#    iso3           countryname  year value
# 0   GRD               Grenada  1990  54.3
# 1   DOM    Dominican Republic  1991  56.4
# 2   BLZ                Belize  1991  46.7
# 3   SUR              Suriname  1992  48.0
# 4   GUY                Guyana  1992  38.2
# 5   JAM               Jamaica  1993  62.0
# 6   HTI                 Haiti  1995  18.0
# 7   DOM    Dominican Republic  1996  63.7
# 8   PRI           Puerto Rico  1996  77.7
# 9   JAM               Jamaica  1997  65.9
# 10  BLZ                Belize  1999  56.1
# 11  DOM    Dominican Republic  1999  69.2
# 12  HTI                 Haiti  2000  28.1
# 13  TTO   Trinidad and Tobago  2000  38.2
# 14  SUR              Suriname  2000  42.1
# 15  CUB                  Cuba  2000  73.3
# 16  DOM    Dominican Republic  2000  64.7
# 17  GUY                Guyana  2000  37.3
# 18  VIR  Virgin Islands, U.S.  2002  78.4
# 19  DOM    Dominican Republic  2002  69.8
# 20  PRI           Puerto Rico  2002  84.1
# 21  JAM               Jamaica  2003  69.0
# 22  GUY                Guyana  2005  34.6
# 23  BLZ                Belize  2006  34.3
# 24  TTO   Trinidad and Tobago  2006  42.5
# 25  DOM    Dominican Republic  2006  61.3
# 26  SUR              Suriname  2006  45.6
# 27  CUB                  Cuba  2006  72.6
# 28  HTI                 Haiti  2006  32.0
# 29  DOM    Dominican Republic  2007  72.9
# 30  GUY                Guyana  2007  34.2
# 31  GUY                Guyana  2009  42.5
# 32  CUB                  Cuba  2011  74.3
# 33  BLZ                Belize  2011  55.2
# 34  HTI                 Haiti  2012  34.5
#
# [35 rows x 4 columns]

# %%
import imp
imp.reload(load_utils)
# Out:
# <module 's3001_load_utils' from '.\\s3001_load_utils.py'>
