# %% [markdown]
# # Build script for Caribbean SIDS RCM water data: Reservoir

# %% [markdown]
# This script moves descriptive data from Generation 1 through Generation 3.

# %%
import os, imp
import pandas as pd

from settings_statmart import *
import utils_statmart as us

import gen3_utils
import gen4_utils

us.verbose = True

# %% [markdown]
# Customize the below per this specfic dataset....

# %%
config = {'gen_1_dir': statmart_facts_gen1 + 'sidsrcm/water/',
     'gen_2_dir': statmart_facts_gen2 + 'sidsrcm/water/',
     'gen_4_dir': statmart_view_gen4 + 'sidsrcm/',
     'description': 'Capacity of water reservoirs and storage tanks',
     'indicator': 'Reservoir capacity',
     'indicator_category': 'Water',
     'indicator_type': 'Reservoirs',
     'multiplier': 1,
     'prefix': 'water-reservoir',
     'suffix': 'sidsrcm',
     'fileprefix': 'reservoirs'}

# %% [markdown]
# Generation 1 - The xls source files this this data have been prepared by an external script. The file name is in the format desalination_country-name.xls. Each file has one worksheet of data, and a second with metadata. The names of these sheet are "data" and "metadata".

# %%
country_dict = us.load_carib_country_dict(key_column="name")
dataset = []
for name in sorted(country_dict.keys()):
    path = config['gen_1_dir'] + config['fileprefix'] + "_" + us.machine_name(name) + ".xls"
    if os.path.exists(path):
        xlfile = pd.ExcelFile(path)
        df = xlfile.parse("data")
        mf = xlfile.parse("metadata")
        dataset.append((country_dict[name]["iso3"], df, mf))
        
dataset[0][1] # This is what the data looks like
# Out:
#      Reservoirs  Capacity
# 0  Bendals Pool       1.8
# 1        Fisher      14.6
# 2  Breaknock #1       5.4
# 3  Breaknock #2      20.1
# 4      Hamilton      27.4
# 5      Dunnings      35.8
# 6      Potworks    1090.0
# 7       Collins      90.0
#
# [8 rows x 2 columns]

# %%
dataset[0][2] # This is what the metadata looks like
# Out:
#                     Description  Note  Source Unit
# Indicator            Reservoirs   NaN     NaN  NaN
# Set Name    Antigua and Barbuda   NaN     NaN  NaN
# Reservoirs                 Name   NaN     NaN  NaN
# Capacity              Capacity    NaN     NaN   MG
#
# [4 rows x 4 columns]

# %% [markdown]
# Generation 2 - Refines the rough csv data from Generation 1 into a standardized csv format common to all data sets. Prepares this data for importing to the database.

# %% [markdown]
# This code follows a fairly standard form, in which it loops through each country's information, writes the data to a .csv file, extracts some metadata and writes that to a .csv file, and then writes a list of all the files that it made to a file called \_PREFIX.csv

# %%
filelist = []
us.mkdirs(config["gen_2_dir"])
for (iso3, df, mf) in dataset:
    us.log(iso3)
    try:
        df.columns = ["description", "value"]
    except Exception: # The data for St Kitts only has one column. We are excluding it for now.
        us.log(sys.exc_info())
        continue
    filestem = config["prefix"] + "_" + iso3.lower() + "_" + config["suffix"]
    filename = filestem + ".csv"
    filepath = config["gen_2_dir"] + filename
    df.to_csv(filepath, encoding="utf8", float_format='%.3f', index=False)
    
    country = us.get_country_by_iso3(iso3)    
    meta = [("name", "%s - %s [SIDS RCM]" % (country, config["indicator"])),
        ("originalsource", mf.ix["Capacity"]["Source"]),
        ("proximatesource", "SIDS RCM"),
        ("dataset", config["indicator"]),
        ("description", config["description"]),
        ("note", mf.ix["Capacity"]["Note"]),
        ("unit", mf.ix["Capacity"]["Unit"]),
        ("category", config["indicator_category"]),
        ("type", config["indicator_type"]),
        ("file", filename),
        ("filehash", us.githash(filepath)),
        ("columns", "description,value")
        ]
 
    metafile = config["gen_2_dir"] + filestem + "_meta.csv"    
    pd.DataFrame(meta,columns = ["key","value"]).to_csv(metafile, encoding="utf8", float_format='%.3f',index=False)
    filelist.append(filestem)
    
pd.DataFrame(filelist).to_csv(config["gen_2_dir"] + "_" + config["prefix"] + ".csv", encoding="utf8", index=False, header=False)
us.log("%i series saved to %s" % (len(filelist), config["gen_2_dir"]))
# Out:
# ATG
# BLZ
# CUB
# (<class 'ValueError'>, ValueError('Length mismatch: Expected axis has 3 elements, new values have 2 elements',), <traceback object at 0x00000000079A2148>)
# DMA
# GRD
# GUY
# (<class 'ValueError'>, ValueError('Length mismatch: Expected axis has 1 elements, new values have 2 elements',), <traceback object at 0x00000000079B59C8>)
# JAM
# SUR
# TTO
# 7 series saved to C:/portal/statmart/data/facts/gen2/sidsrcm/water/

# %% [markdown]
# Generation 3 - Load the Generation 2 data into the database.

# %%
data_list = gen3_utils.get_gen2_data(config)
observation_fields = "series, description, value, locationid"
gen3_utils.standard_load_from_data_list(data_list, observation_fields)
data_list
# Out:
# [('water-reservoir_atg_sidsrcm',
#   'ATG',
#   key
# name               Antigua and Barbuda - Reservoir capcity [SIDS ...
# originalsource                                                   NaN
# proximatesource                                             SIDS RCM
# dataset                                            Reservoir capcity
# description           Capacity of water reservoies and storage tanks
# note                                                             NaN
# unit                                                              MG
# category                                                       Water
# type                                                      Reservoirs
# file                                 water-reservoir_atg_sidsrcm.csv
# filehash                    83259ec84412b17822235718f2fe346a37017bde
# columns                                            description,value
# Name: value, dtype: object,
#       description   value
# 0  Bendals Pool     1.8
# 1        Fisher    14.6
# 2  Breaknock #1     5.4
# 3  Breaknock #2    20.1
# 4      Hamilton    27.4
# 5      Dunnings    35.8
# 6      Potworks  1090.0
# 7       Collins    90.0
#
# [8 rows x 2 columns]),
#  ('water-reservoir_blz_sidsrcm',
#   'BLZ',
#   key
# name                        Belize - Reservoir capcity [SIDS RCM]
# originalsource                                                NaN
# proximatesource                                          SIDS RCM
# dataset                                         Reservoir capcity
# description        Capacity of water reservoies and storage tanks
# note                                                          NaN
# unit                                                           MG
# category                                                    Water
# type                                                   Reservoirs
# file                              water-reservoir_blz_sidsrcm.csv
# filehash                 b7f9e835dc6daab36ce661da9480421145fd7188
# columns                                         description,value
# Name: value, dtype: object,
#       description     value
# 0    Calilo Dam  27276.17
# 1  Mollejon Dam    376.15
# 2      Vaca Dam   2661.63
#
# [3 rows x 2 columns]),
#  ('water-reservoir_dma_sidsrcm',
#   'DMA',
#   key
# name                      Dominica - Reservoir capcity [SIDS RCM]
# originalsource                                                NaN
# proximatesource                                          SIDS RCM
# dataset                                         Reservoir capcity
# description        Capacity of water reservoies and storage tanks
# note                                                          NaN
# unit                                                           MG
# category                                                    Water
# type                                                   Reservoirs
# file                              water-reservoir_dma_sidsrcm.csv
# filehash                 f7ccf234337151db23efcb7b7bdf5c2195419b08
# columns                                         description,value
# Name: value, dtype: object,
#                    description  value
# 0                     Jimmit  0.060
# 1                     Mahaut  0.060
# 2                    Belfast  0.012
# 3                        NaN  0.010
# 4                  Checkhall  0.010
# 5                     Antrim  0.200
# 6                  Canefield  0.140
# 7               Morne Daniel  0.030
# 8    Stockfarm/Simon Bolivar  0.060
# 9             Bellevue Rawle  0.008
# 10                  Goodwill  0.170
# 11               St. Aroment  0.068
# 12                    Roseau  0.080
# 13                 Kingshill  0.018
# 14               Morne Bruce  0.500
# 15               Morne Bruce  0.016
# 16                   Fortune  0.015
# 17            Castle Comfort  0.004
# 18                Wall House  0.019
# 19         Loubiere/Madrelle  0.015
# 20             Pointe Michel  0.015
# 21                      Mero  0.020
# 22                St. Joseph  0.120
# 23                 Salisbury  0.030
# 24            Morne Rachette  0.015
# 25                  Colihaut  0.010
# 26                   Dublanc  0.012
# 27                    Bioche  0.007
# 28  Portsmouth/Lagoon/Chance  0.120
# 29         Glanvillia/Balvin  0.015
# 30      Cottage, Mne. Soleil  0.008
# 31                   Clifton  0.012
# 32                  Capuchin  0.030
# 33           Upper Peneville  0.011
# 34                     Embas  0.030
# 35            Lower Penville  0.010
# 36               Vielle Case  0.016
# 37                     Coton  0.010
# 38                Moore Park  0.015
# 39                   Thibaut  0.011
# 40               Paix Bouche  0.010
# 41                    Bornes  0.007
# 42                 Dos D'Ane  0.009
# 43            Bense/Hamstead  0.012
# 44                Calibishie  0.024
# 45                    Wesley  0.060
# 46              Woodfordhill  0.060
# 47     Marigot/Melville Hall  0.060
# 48              Castle Bruce  0.015
# 49                 Good Hope  0.015
# 50              Saint Sauver  0.015
# 51          Petite Soufriere  0.015
# 52               Morne Jaune  0.010
# 53           Riviere Cyrique  0.012
# 54                 La Plaine  0.011
# 55            Carse O Gowrie  0.004
# 56                   Delices  0.017
# 57            Petite Savanne  0.015
# 58                 Bagatelle  0.015
# 59                Quart Bois  0.015
#                          ...    ...
#
# [84 rows x 2 columns]),
#  ('water-reservoir_grd_sidsrcm',
#   'GRD',
#   key
# name                          Grenada - Reservoir capcity [SIDS RCM]
# originalsource     The Caribbean Conservation Association. 1991. ...
# proximatesource                                             SIDS RCM
# dataset                                            Reservoir capcity
# description           Capacity of water reservoies and storage tanks
# note                                        Figures recorded in 1991
# unit                                                              MG
# category                                                       Water
# type                                                      Reservoirs
# file                                 water-reservoir_grd_sidsrcm.csv
# filehash                    add8375c8fa85cb4cb4205cc39a4689fc7c7c2e5
# columns                                            description,value
# Name: value, dtype: object,
#           description  value
# 0     Annandale Dam      2
# 1     Mardigras Dam      2
# 2  Grand Etang Lake    NaN
#
# [3 rows x 2 columns]),
#  ('water-reservoir_jam_sidsrcm',
#   'JAM',
#   key
# name                       Jamaica - Reservoir capcity [SIDS RCM]
# originalsource          Water Resources Authority, Jamaica. 2012.
# proximatesource                                          SIDS RCM
# dataset                                         Reservoir capcity
# description        Capacity of water reservoies and storage tanks
# note                                                          NaN
# unit                                                           MG
# category                                                    Water
# type                                                   Reservoirs
# file                              water-reservoir_jam_sidsrcm.csv
# filehash                 946acc52ac87416046ef49c24ba8ff305d987fca
# columns                                         description,value
# Name: value, dtype: object,
#     description  value
# 0        Mona  808.5
# 1   Hermitage  393.5
#
# [2 rows x 2 columns]),
#  ('water-reservoir_sur_sidsrcm',
#   'SUR',
#   key
# name                      Suriname - Reservoir capcity [SIDS RCM]
# originalsource                                                NaN
# proximatesource                                          SIDS RCM
# dataset                                         Reservoir capcity
# description        Capacity of water reservoies and storage tanks
# note                                                          NaN
# unit                                                           MG
# category                                                    Water
# type                                                   Reservoirs
# file                              water-reservoir_sur_sidsrcm.csv
# filehash                 75016f965728facd54ef29a6a01a1d7d50aa757d
# columns                                         description,value
# Name: value, dtype: object,
#                                   description  value
# 0  Prof. Dr. Ir. Van Blommenstein Reservoir  55000
#
# [1 rows x 2 columns]),
#  ('water-reservoir_tto_sidsrcm',
#   'TTO',
#   key
# name               Trinidad and Tobago - Reservoir capcity [SIDS ...
# originalsource     Public Education Centre Water & Sewerage Autho...
# proximatesource                                             SIDS RCM
# dataset                                            Reservoir capcity
# description           Capacity of water reservoies and storage tanks
# note                                                             NaN
# unit                                                              MG
# category                                                       Water
# type                                                      Reservoirs
# file                                 water-reservoir_tto_sidsrcm.csv
# filehash                    dbdadc3060daf37091da9271f64a5ea052489e40
# columns                                            description,value
# Name: value, dtype: object,
#       description  value
# 0         Navet   4200
# 1        Hollis   1000
# 2        Caroni  10000
# 3  Hillsborough    269
#
# [4 rows x 2 columns])]

# %% [markdown]
# Here are the names of the series:

# %%
filelist
# Out:
# ['water-reservoir_atg_sidsrcm',
#  'water-reservoir_blz_sidsrcm',
#  'water-reservoir_dma_sidsrcm',
#  'water-reservoir_grd_sidsrcm',
#  'water-reservoir_jam_sidsrcm',
#  'water-reservoir_sur_sidsrcm',
#  'water-reservoir_tto_sidsrcm']
