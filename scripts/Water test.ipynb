# %%
import pandas as pd

# %%
proot = "C:/Users/rwilliams/Documents/portal/"
water = proot + "rcm\data/water.xlsx"

# %%
wdate = pd.ExcelFile(water)
wdate.sheet_names
# Out:
# ['Description (2)',
#  '1ai. Surface run-off',
#  '1aii. Surface water quality',
#  '1aiii. Reservoirs',
#  '1b. Ground Water Quality',
#  '1c. Desal water',
#  '2. Rainfall',
#  '3a. Aquifer recharge',
#  '3b. Run-off & Poll. impacts',
#  '4. Water avail by region',
#  '4b. Water production',
#  '5a. National water demand',
#  '5ai. Water consumption',
#  '5b. Sectoral water demand',
#  '5c. Water demand by region',
#  '5d. Households connected',
#  '6a. Water fees',
#  '6b. Water costs',
#  '7a. Wastewater costs',
#  '8a. Income and prices',
#  '8b. Income ',
#  '9a. Agriculture',
#  '9bi. Visitor arrivals',
#  '9bia. Av. Vis Expen.',
#  '9bii. Tourism visitor types',
#  '9biii. Tourism amenities',
#  'c. Industrial',
#  '9di..Residential house char.',
#  'Water use growth',
#  '9dii. Residential pipe borne',
#  '9.diii. Residential sanitation',
#  '10a. Bottled water',
#  '10b. Water quality studies',
#  '11a. Employment in water',
#  '11b. Water HouseBudget',
#  '11c. Potable water Access',
#  '12a. Energy Sources',
#  '12b. Energy Prices',
#  '12c. Generators used',
#  '12d. Eff. indicators',
#  '12e. Replacement costs',
#  '12f. Location of water facil.',
#  '13. River inflow at boundaries',
#  '14. Desalination.IWRM plans',
#  '15. Water pricing.metering',
#  '16. Water loss reduction ',
#  '17. Surface water provision',
#  'Appendices',
#  'Water avail by region (2)',
#  'Suriname Water Map',
#  'Description']

# %%
#country = 'St Lucia '
#country = 'Trinidad and Tobago'
#ountry = 'Cuba'
#country = 'Suriname'
def graphData(dframe, indicator, country):
    worksheet = dframe.parse(indicator, header=2)
    worksheet = worksheet[['Year',country]]
    worksheet = worksheet[pd.notnull(worksheet['Year'])]
    return worksheet.plot(x="Year",y=country, title=indicator + ": " + country, kind="line")

# %%
def diceData(dframe, indicator, country):
    worksheet = dframe.parse(indicator, header=2)
    worksheet = worksheet[['Year',country]]
    worksheet = worksheet[pd.notnull(worksheet['Year'])]
    return worksheet

data = diceData(wdate,'5ai. Water consumption','Jamaica')
print (data)
# Out:
#                                       Year       Jamaica
# 2                                     1996  17605.658853
# 3                                     1997  20968.324956
# 4                                     1998  22350.390183
# 5                                     1999  22903.832187
# 6                                     2000  21956.425704
# 7                                     2001  20646.510309
# 8                                     2002  20917.732086
# 9                                     2003  21189.393801
# 10                                    2004  20837.443401
# 11                                    2005  20768.527113
# 24                                    2006  20967.005142
# 37                                    2007  21956.469698
# 50                                    2008  19944.897187
# 63                                    2009           NaN
# 76                                    2010           NaN
# 96                              Dominica             NaN
# 97       Dominica Water & Sewerage Company           NaN
# 99                                 Jamaica           NaN
# 100  Economic and Social Survey of Jamaica           NaN
#
# [19 rows x 2 columns]

# %%
plot = graphData(wdate,'5ai. Water consumption','Jamaica')

# %%
plot1 = graphData(wdate,'5a. National water demand','Trinidad and Tobago')

# %%
plot2 = graphData(wdate,'4b. Water production','Trinidad & Tobago')

# %%
ind1 = '5a. National water demand'
ind2 = '4b. Water production'

country = 'Trinidad and Tobago'

def getData(dframe, indicator, country):
    worksheet = dframe.parse(indicator, header=2)
    worksheet = worksheet[['Year',country]]
    worksheet = worksheet[pd.notnull(worksheet['Year'])]
    worksheet['Year'] = worksheet['Year'].astype(int)
    return worksheet

def plotIndicators(dframe, ind1, ind2, country):
    w1 = getData(dframe,ind1,country)
    w2 = getData(dframe,ind2,country)
    combined = pd.merge(w1,w2,on="Year")
    combined.columns = ['Year',ind1, ind2]
    combined.plot(x="Year", title=country, kind="line")

plotIndicators(wdate, ind1, ind2, country)    

df = getData(wdate, ind1, country) 
df.to_csv("c:/Users/rwilliams/Documents/portal/ttwater.csv", index=False, float_format='%.3f')

# %%
ind3 = '5ai. Water consumption'
country = 'Jamaica'
plotIndicators(wdate, ind2, ind3, country)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-17820b4a88d3> in <module>()
#       1 ind3 = '5ai. Water consumption'
#       2 country = 'Jamaica'
# ----> 3 plotIndicators(wdate, ind2, ind3, country)
#
# <ipython-input-33-321f2549d51b> in plotIndicators(dframe, ind1, ind2, country)
#      14 def plotIndicators(dframe, ind1, ind2, country):
#      15     w1 = getData(dframe,ind1,country)
# ---> 16     w2 = getData(dframe,ind2,country)
#      17     combined = pd.merge(w1,w2,on="Year")
#      18     combined.columns = ['Year',ind1, ind2]
#
# <ipython-input-33-321f2549d51b> in getData(dframe, indicator, country)
#       9     worksheet = worksheet[['Year',country]]
#      10     worksheet = worksheet[pd.notnull(worksheet['Year'])]
# ---> 11     worksheet['Year'] = worksheet['Year'].astype(int)
#      12     return worksheet
#      13
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, raise_on_error)
#    1781
#    1782         mgr = self._data.astype(
# -> 1783             dtype, copy=copy, raise_on_error=raise_on_error)
#    1784         return self._constructor(mgr).__finalize__(self)
#    1785
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\core\internals.py in astype(self, *args, **kwargs)
#    2306
#    2307     def astype(self, *args, **kwargs):
# -> 2308         return self.apply('astype', *args, **kwargs)
#    2309
#    2310     def convert(self, *args, **kwargs):
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\core\internals.py in apply(self, f, *args, **kwargs)
#    2265
#    2266             else:
# -> 2267                 applied = getattr(blk, f)(*args, **kwargs)
#    2268
#    2269             if isinstance(applied, list):
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, raise_on_error, values)
#     402     def astype(self, dtype, copy=False, raise_on_error=True, values=None):
#     403         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 404                             values=values)
#     405
#     406     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, raise_on_error, values, klass)
#     419             # force the copy here
#     420             if values is None:
# --> 421                 values = com._astype_nansafe(self.values, dtype, copy=True)
#     422             newb = make_block(values, self.items, self.ref_items,
#     423                               ndim=self.ndim, placement=self._ref_locs,
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\core\common.py in _astype_nansafe(arr, dtype, copy)
#    2128     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#    2129         # work around NumPy brokenness, #1987
# -> 2130         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    2131     elif issubclass(dtype.type, compat.string_types):
#    2132         return lib.astype_str(arr.ravel()).reshape(arr.shape)
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\lib.pyd in pandas.lib.astype_intsafe (pandas\lib.c:12415)()
#
# C:\WinPython\python-3.3.3\lib\site-packages\pandas\lib.pyd in util.set_value_at (pandas\lib.c:47961)()
#
# ValueError: invalid literal for int() with base 10: 'Dominica  '
